# %%
import pandas as pd

# %%
df = pd.read_excel("default_of_credit_card_clients__courseware_version_1_21_19.xls")

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df['ID'].nunique()
# Out:
# 29687

# %%
df.shape
# Out:
# (30000, 25)

# %%
id_counts = df['ID'].value_counts()
id_counts.head()
# Out:
# ad23fe5c-7b09    2
# 1fb3e3e6-a68d    2
# 89f8f447-fca8    2
# 7c9b7473-cc2f    2
# 90330d02-82d9    2
# Name: ID, dtype: int64

# %%
id_counts.value_counts()
# Out:
# 1    29374
# 2      313
# Name: ID, dtype: int64

# %%
dupe_mask = id_counts == 2
dupe_mask[0:5]
# Out:
# ad23fe5c-7b09    True
# 1fb3e3e6-a68d    True
# 89f8f447-fca8    True
# 7c9b7473-cc2f    True
# 90330d02-82d9    True
# Name: ID, dtype: bool

# %%
id_counts.index[0:5]
# Out:
# Index(['ad23fe5c-7b09', '1fb3e3e6-a68d', '89f8f447-fca8', '7c9b7473-cc2f',
#        '90330d02-82d9'],
#       dtype='object')

# %%
dupe_ids = id_counts.index[dupe_mask]

# %%
dupe_ids = list(dupe_ids)
len(dupe_ids)
# Out:
# 313

# %%
dupe_ids[0:5]
# Out:
# ['ad23fe5c-7b09',
#  '1fb3e3e6-a68d',
#  '89f8f447-fca8',
#  '7c9b7473-cc2f',
#  '90330d02-82d9']

# %%
dupe_ids[0:3]
# Out:
# ['ad23fe5c-7b09', '1fb3e3e6-a68d', '89f8f447-fca8']

# %%
df.loc[df['ID'].isin(dupe_ids[0:3]),:].head(10)
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 5033   89f8f447-fca8     320000    2          2         1   32     0      0
# 5133   89f8f447-fca8          0    0          0         0    0     0      0
# 16727  1fb3e3e6-a68d      80000    1          2         2   33     2      2
# 16827  1fb3e3e6-a68d          0    0          0         0    0     0      0
# 29685  ad23fe5c-7b09      50000    1          3         1   32     0      0
# 29785  ad23fe5c-7b09          0    0          0         0    0     0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 5033       0      0  ...     169371     172868     150827      8000      8000
# 5133       0      0  ...          0          0          0         0         0
# 16727      0      0  ...      27394      29922      31879         0      2000
# 16827      0      0  ...          0          0          0         0         0
# ...

# %%
df_zero_mask = df == 0

# %%
feature_zero_mask = df_zero_mask.iloc[:,1:].all(axis=1)

# %%
sum(feature_zero_mask)
# Out:
# 315

# %%
df_clean_1 = df.loc[-feature_zero_mask, :].copy()

# %%
df_clean_1.shape
# Out:
# (29685, 25)

# %%
df_clean_1['ID'].nunique()
# Out:
# 29685

# %%
df_clean_1.loc[df_clean_1['SEX'] == 2]
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 7      d6e1911b-54d0     100000    2          2         2   23     0     -1
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29180  7f90d848-2479     140000    2          2         1   60     2      2
# 29181  9fed3d29-5af1     170000    2          3         1   57     0      0
# 29182  b0817fc6-d2bf     280000    2          1         1   56    -2     -2
# 29185  a464d623-b7cb      50000    2          3         2   55     2      0
# 29282  7ec131f0-376a      80000    2          1         3   25     0     -1
#
# ...

# %%
df_clean_1.loc[df_clean_1['SEX'] == 2].shape
# Out:
# (17910, 25)

# %%
valid_pay_1_mask = df_clean_1['PAY_1'] != 'Not available'
valid_pay_1_mask[0:5]
# Out:
# C:\Users\fogac\AppData\Local\Temp\ipykernel_13528\3269616069.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   valid_pay_1_mask[0:5]
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: PAY_1, dtype: bool

# %%
sum(valid_pay_1_mask)
df_clean_2 = df_clean_1.loc[valid_pay_1_mask, :].copy()
df_clean_2.shape
df_clean_2['PAY_1'] = df_clean_2['PAY_1'].astype('int64')
df_clean_2[['PAY_1', 'PAY_2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26664 entries, 0 to 29999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PAY_1   26664 non-null  int64
#  1   PAY_2   26664 non-null  int64
# dtypes: int64(2)
# memory usage: 624.9 KB

# %%
import matplotlib.pyplot as plot # importa o pacote de plotagem
# renderiza a plotagem automaticamente
# %matplotlib inline
import matplotlib as mpl # recurso adicional de plotagem
mpl.rcParams['figure.dpi'] = 400 # figuras em alta resolução

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].hist()
# Out:
# array([[<Axes: title={'center': 'LIMIT_BAL'}>,
#         <Axes: title={'center': 'AGE'}>]], dtype=object)

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].describe()
df_clean_2['EDUCATION'].value_counts()
df_clean_2['EDUCATION'].replace(to_replace=[0, 5, 6], value=4, inplace=True)
df_clean_2['EDUCATION'].value_counts()
df_clean_2['MARRIAGE'].value_counts()
df_clean_2['MARRIAGE'].replace(to_replace=0, value=3, inplace=True)
df_clean_2['MARRIAGE'].value_counts()
# Out:
# 2    14158
# 1    12172
# 3      334
# Name: MARRIAGE, dtype: int64

# %%
df_clean_2['EDUCATION_CAT'] = 'none'
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
cat_mapping = {
1: "graduate school",
2: "university",
3: "high school",
4: "others"
}
df_clean_2['EDUCATION_CAT'] = df_clean_2['EDUCATION'].map(cat_mapping)
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
edu_ohe = pd.get_dummies(df_clean_2['EDUCATION_CAT'])
edu_ohe.head(10)
df_with_ohe = pd.concat([df_clean_2, edu_ohe], axis=1)
df_with_ohe[['EDUCATION_CAT', 'graduate school','high school', 'university', 'others']].head(10)
# Out:
#      EDUCATION_CAT  graduate school  high school  university  others
# 0       university                0            0           1       0
# 1       university                0            0           1       0
# 2       university                0            0           1       0
# 3       university                0            0           1       0
# 4       university                0            0           1       0
# 5  graduate school                1            0           0       0
# 6  graduate school                1            0           0       0
# 7       university                0            0           1       0
# 8      high school                0            1           0       0
# 9      high school                0            1           0       0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# amostre utilizando holdout
X_train, X_test, y_train, y_test = train_test_split(
df['EDUCATION'].values.reshape(-1, 1), df['default payment next month'].values,
test_size=0.2, random_state=24)
# crie um objeto para regressao logistica
example_lr = LogisticRegression()
# treine o modelo utilizando os dados proprios para treino
example_lr.fit(X_train, y_train)
# teste o modelo utilizando os dados proprios para teste
y_pred = example_lr.predict(X_test)

# %%
P = sum(y_test)
P
# Out:
# 1346

# %%
TP = sum( (y_test == 1) & (y_pred == 1) )
TP
# Out:
# 0

# %%
TPR = TP/P
TPR
# Out:
# 0.0

# %%
FN = sum( (y_test == 1) & (y_pred == 0) )

# %%
FN
# Out:
# 1346

# %%
FNR = FN/P
FNR
# Out:
# 1.0

# %%
N = sum(y_test == 0)
N
# Out:
# 4654

# %%
TN = sum( (y_test == 0) & (y_pred == 0) )
TN
# Out:
# 4654

# %%
FP = sum( (y_test == 0) & (y_pred == 1) )
FP
# Out:
# 0

# %%
TNR = TN/N
FPR = FP/N
print(f'The true negative rate is {TNR} and teh false negative rate is {FPR}')
# Out:
# The true negative rate is 1.0 and teh false negative rate is 0.0

# %%
bill_feats = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
pay_amt_feats = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3',
'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
df_clean_2.describe()
# Out:
#            LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count   26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean   167919.054905      1.603060      1.842334      1.556031     35.505213
# std    129839.453081      0.489272      0.744661      0.521463      9.227442
# min     10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%     50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%    140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%    240000.000000      2.000000      2.000000      2.000000     41.000000
# max    800000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df_with_ohe[bill_feats].hist(bins = 20,layout=(2,3))
df_with_ohe[pay_amt_feats].describe()
# Out:
#             PAY_AMT1      PAY_AMT2       PAY_AMT3       PAY_AMT4  \
# count   26664.000000  2.666400e+04   26664.000000   26664.000000
# mean     5704.085771  5.881110e+03    5259.514964    4887.048717
# std     16699.398632  2.121431e+04   17265.439561   15956.349371
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%      1000.000000  8.020000e+02     390.000000     294.750000
# 50%      2114.500000  2.007000e+03    1822.000000    1500.000000
# 75%      5027.000000  5.000000e+03    4556.250000    4050.500000
# max    873552.000000  1.227082e+06  889043.000000  621000.000000
#
#             PAY_AMT5       PAY_AMT6
# count   26664.000000   26664.000000
# mean     4843.729973    5257.843047
# std     15311.721795   17635.468185
# min         0.000000       0.000000
# 25%       242.750000     111.000000
# 50%      1500.000000    1500.000000
# 75%      4082.750000    4015.000000
# max    426529.000000  528666.000000

# %%
df_with_ohe[pay_amt_feats].hist(bins = 20,layout=(2,3), xrot = 45)
# Out:
# array([[<Axes: title={'center': 'PAY_AMT1'}>,
#         <Axes: title={'center': 'PAY_AMT2'}>,
#         <Axes: title={'center': 'PAY_AMT3'}>],
#        [<Axes: title={'center': 'PAY_AMT4'}>,
#         <Axes: title={'center': 'PAY_AMT5'}>,
#         <Axes: title={'center': 'PAY_AMT6'}>]], dtype=object)

# %%
mask = df_with_ohe[pay_amt_feats] == 0
mask
# Out:
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0          True     False      True      True      True      True
# 1          True     False     False     False      True     False
# 2         False     False     False     False     False     False
# 3         False     False     False     False     False     False
# 4         False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...
# 29995     False     False     False     False     False     False
# 29996     False     False     False     False      True      True
# 29997      True      True     False     False     False     False
# 29998     False     False     False     False     False     False
# 29999     False     False     False     False     False     False
#
# [26664 rows x 6 columns]

# %%
df_mask = df.loc[df_with_ohe[pay_amt_feats].isin[mask, :]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13528\3518153301.py in <module>
# ----> 1 df_mask = df.loc[df_with_ohe[pay_amt_feats].isin[mask, :]]
#
# TypeError: 'method' object is not subscriptable

# %%
df_mask
# Out:
#         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0      NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 1      NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 2      NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 3      NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 4      NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# ...    ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 29996  NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 29997  NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 29998  NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
# 29999  NaN        NaN  NaN        NaN       NaN  NaN    NaN    NaN    NaN
#
#        PAY_4  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...
